# %% [markdown]
# ### LightRAG Markdown Ingestion

# %% [markdown]
# #### Reset LightRag (Optional)

# %%
from pathlib import Path
import shutil

LIGHTRAG_DIR = Path(".rag/lightrag")
if LIGHTRAG_DIR.exists():
    shutil.rmtree(LIGHTRAG_DIR)
    print(f"Removed existing LightRAG workspace: {LIGHTRAG_DIR}")
LIGHTRAG_DIR.mkdir(parents=True, exist_ok=True)
# Out:
# Removed existing LightRAG workspace: .rag/lightrag

# %% [markdown]
# #### LightRag Ingestion

# %%
import os, sys
from pathlib import Path
from dotenv import load_dotenv

repo_root = Path.cwd().resolve().parent
if str(repo_root) not in sys.path:
    sys.path.insert(0, str(repo_root))

load_dotenv(repo_root / ".env", override=True)

from KnowledgeGraph.LightRAG.lightrag_runner import (
    ChunkingConfig,
    FallbackConfig,
    build_lightrag,
    ensure_initialized,
    ingest_markdown_files,
    DEFAULT_SOURCE_DIR,
)

source_dir_env = os.getenv("LIGHTRAG_SOURCE_DIR")
source_dir = Path(source_dir_env) if source_dir_env else DEFAULT_SOURCE_DIR
if not source_dir.is_absolute():
    source_dir = (repo_root / source_dir).resolve()

MAX_WORKERS = 40  # set an integer to override LightRAG defaults
chunk_cfg = ChunkingConfig.from_env()
fallback_cfg = FallbackConfig.from_env()

rag = build_lightrag()
await ensure_initialized(rag)

ingested = await ingest_markdown_files(
    rag,
    source_dir=source_dir,
    max_workers=MAX_WORKERS,
    show_progress=True,
    show_chunk_progress=True,
    chunking=chunk_cfg,
    fallback=fallback_cfg,
)

print(f"Ingested {len(ingested)} markdown files from {source_dir}.")
# Out:
# INFO: [_] Created new empty graph file: .rag/lightrag/graph_chunk_entity_relation.graphml
# INFO:nano-vectordb:Init {'embedding_dim': 3072, 'metric': 'cosine', 'storage_file': '.rag/lightrag/vdb_entities.json'} 0 data
# INFO:nano-vectordb:Init {'embedding_dim': 3072, 'metric': 'cosine', 'storage_file': '.rag/lightrag/vdb_relationships.json'} 0 data
# INFO:nano-vectordb:Init {'embedding_dim': 3072, 'metric': 'cosine', 'storage_file': '.rag/lightrag/vdb_chunks.json'} 0 data
# LightRAG ingest:   0%|          | 0/10 [00:00<?, ?file/s]WARNING: Ignoring document ID (already exists): doc-3e38e39869541f028371688baefa7699 (2025-04-27_en.md)
# WARNING: No new unique documents were found.
# INFO: Reset 1 documents from PROCESSING/FAILED to PENDING status
# INFO: Processing 1 document(s)
# INFO: Extracting stage 1/1: 2025-04-27_en.md
# INFO: Processing d-id: doc-3e38e39869541f028371688baefa7699
# INFO: Embedding func: 8 new workers initialized (Timeouts: Func: 30s, Worker: 60s, Health Check: 75s)
# INFO: Chunk 1 of 2236 extracted 44 Ent + 42 Rel chunk-4eed60346530c72dea17daf43f3318fb
# INFO: Chunk 2 of 2236 extracted 0 Ent + 0 Rel chunk-9efc314b65237d5d646e1b817372afc6
# INFO: Chunk 3 of 2236 extracted 16 Ent + 18 Rel chunk-fa9ee2ae570a6ae3708c759feb953b1a
# INFO: Chunk 4 of 2236 extracted 6 Ent + 4 Rel chunk-4faf92732dae73a4b2141be9bcf25730
# INFO: Chunk 5 of 2236 extracted 5 Ent + 7 Rel chunk-3ed56cd468797d5c2a6b6c293fbe61ee
# INFO: Chunk 6 of 2236 extracted 2 Ent + 1 Rel chunk-25606e7c6944f39d6828675b3da3cd6e
# INFO: Chunk 7 of 2236 extracted 7 Ent + 9 Rel chunk-aa04715f7682d9d38527fac25b86dd7e
# INFO: Chunk 8 of 2236 extracted 1 Ent + 0 Rel chunk-d0144e1be3a232efb03cd45aba63eb37
# INFO: Chunk 9 of 2236 extracted 18 Ent + 17 Rel chunk-9c45a100aa08407e734a2147cdeef0c4
# INFO: Chunk 10 of 2236 extracted 3 Ent + 3 Rel chunk-8c3c7ed0387ee980d780d0fd4b9060c9
# INFO: Chunk 11 of 2236 extracted 1 Ent + 0 Rel chunk-16e0f30ff5977e3221458968d7f5d699
# INFO: Chunk 12 of 2236 extracted 18 Ent + 18 Rel chunk-f876a62be3a8656e4b9eda2193e86852
# INFO: Chunk 13 of 2236 extracted 2 Ent + 1 Rel chunk-58ddf31342d57fd081423adfeb0bde4a
# INFO: Chunk 14 of 2236 extracted 2 Ent + 1 Rel chunk-c4cff758aeefc376a4e6e1e437611a5e
# INFO: Chunk 15 of 2236 extracted 5 Ent + 5 Rel chunk-14e8c77109c7e89780ddd9d9cfe5ecb7
# INFO: Chunk 16 of 2236 extracted 6 Ent + 6 Rel chunk-d0ecd8d7e5de78956426ac2cb00a90f1
# INFO: Chunk 17 of 2236 extracted 9 Ent + 9 Rel chunk-f11724df5509b250027fb90e4b7e4528
# INFO: Chunk 18 of 2236 extracted 6 Ent + 5 Rel chunk-1f039081b030d739ab2415730497a011
# INFO: Chunk 19 of 2236 extracted 11 Ent + 12 Rel chunk-6f8e8a3d3ec6b6187738cfb470ecb671
# INFO: Chunk 20 of 2236 extracted 6 Ent + 6 Rel chunk-1826bf8f8a2eba83c629dcab015bc72f
# INFO: Chunk 21 of 2236 extracted 6 Ent + 5 Rel chunk-b1c5448f2167de073fb92aaf70dbd5e3
# INFO: Chunk 22 of 2236 extracted 5 Ent + 5 Rel chunk-573d837128fce2299768ae8a5dd09f71
# INFO: Chunk 23 of 2236 extracted 5 Ent + 5 Rel chunk-966f5be5507679e5e3660e53da2f5a8b
# INFO: Chunk 24 of 2236 extracted 9 Ent + 13 Rel chunk-94dcd460bb16108bc849165bec264982
# INFO: Chunk 25 of 2236 extracted 2 Ent + 1 Rel chunk-c05b672031643eaf8253a93f723abc96
# INFO: Chunk 26 of 2236 extracted 5 Ent + 6 Rel chunk-159373ebcfb6d2b092fddb1dfaa59a2b
# INFO: Chunk 27 of 2236 extracted 11 Ent + 11 Rel chunk-d20cba3d2bfb5b00733fd0d50446fe6b
# INFO: Chunk 28 of 2236 extracted 5 Ent + 7 Rel chunk-b61905fcfcbdba1f563c265b1b69c31f
# INFO: Chunk 29 of 2236 extracted 6 Ent + 8 Rel chunk-90cf85a3911f47201fc43f5f0ea8b4ee
# INFO: Chunk 30 of 2236 extracted 44 Ent + 83 Rel chunk-2f78bc918514c375f328645fc52c5396
# INFO: Chunk 31 of 2236 extracted 8 Ent + 9 Rel chunk-4855f285317d1f8f56e961899d4ed395
# INFO: Chunk 32 of 2236 extracted 5 Ent + 7 Rel chunk-af0dd43be396db1f8ad596054f7388ba
# INFO: Chunk 33 of 2236 extracted 18 Ent + 18 Rel chunk-d9e0156ac4712aeae4de6e7f49d2cde9
# INFO: Chunk 34 of 2236 extracted 11 Ent + 11 Rel chunk-425f4f8287cce5baaab847b752d9d3e6
# INFO: Chunk 35 of 2236 extracted 2 Ent + 1 Rel chunk-6bef963f2df62107af2b3f578b91c788
# INFO: Chunk 36 of 2236 extracted 3 Ent + 2 Rel chunk-61a45f2da4e259f304197e105d5b8956
# INFO: Chunk 37 of 2236 extracted 5 Ent + 5 Rel chunk-9c378981c3315f4e363f37f2c09d3619
# INFO: Chunk 38 of 2236 extracted 5 Ent + 5 Rel chunk-f1c38f2cbd6b3072cf011b0bb2a653df
# INFO: Chunk 39 of 2236 extracted 13 Ent + 12 Rel chunk-bce378ab1566db1bd306846480aa8cfb
# INFO: Chunk 40 of 2236 extracted 6 Ent + 5 Rel chunk-dc17e62d83cd53bccd9c79d35cc37742
# INFO: Chunk 41 of 2236 extracted 8 Ent + 12 Rel chunk-c178e5e3eb4e651955004995c3c80fad
# INFO: Chunk 42 of 2236 extracted 26 Ent + 25 Rel chunk-96c16caf9eaa1d0a312dc3571c9edd15
# INFO: Chunk 43 of 2236 extracted 14 Ent + 16 Rel chunk-e0068b96a35c58429642aea5390c7b19
# INFO: Chunk 44 of 2236 extracted 5 Ent + 5 Rel chunk-43fcc23eea7b2b36e9ad5c8a3f0c2329
# INFO: Chunk 45 of 2236 extracted 17 Ent + 17 Rel chunk-af0069091938e3b58aa7bb6a9aa2b256
# INFO: Chunk 46 of 2236 extracted 4 Ent + 4 Rel chunk-c467d349c632bc984cbc9ea1026a14d8
# INFO: Chunk 47 of 2236 extracted 14 Ent + 13 Rel chunk-f3a53329738ba631d0c89c1507e2529b
# INFO: Chunk 48 of 2236 extracted 3 Ent + 2 Rel chunk-6b6dbd43a1f88d0b28861a5edc98ddcc
# WARNING: chunk-c88d25657e8fd92062fc9a4379984b7d: LLM output format error; found 2/4 feilds on ENTITY `Inspector<#|#>Concept<#|#>The Inspector is the official empowered by Article 1/52 to request testimony, information, or documents from debtors, creditors, central bank units, licensed persons, regulatory bodies, or other entities for assigned tasks.` @ `N/A`
# WARNING: chunk-c88d25657e8fd92062fc9a4379984b7d: LLM output format error; found 3/4 feilds on ENTITY `Central Bank` @ `Organization<#|#>The Central Bank is the national banking authority referenced as an entity whose subject units may be required to provide information or documents to the Inspector.`
# WARNING: chunk-c88d25657e8fd92062fc9a4379984b7d: LLM output format error; found 2/4 feilds on ENTITY `Authority<#|#>Organization<#|#>The Authority is the regulatory authority mentioned as a body whose licensed persons may be required to provide information or documents to the Inspector.` @ `N/A`
# WARNING: chunk-c88d25657e8fd92062fc9a4379984b7d: LLM output format error; found 2/4 feilds on ENTITY `Regulatory Bodies<#|#>Organization<#|#>Regulatory Bodies are governmental oversight entities referenced as possible request sources to the Bankruptcy Judge and as sources from which the Inspector may request information.` @ `N/A`
# WARNING: chunk-c88d25657e8fd92062fc9a4379984b7d: LLM output format error; found 3/4 feilds on ENTITY `Kuwait Finance House` @ `Organization<#|#>Kuwait Finance House is one of the banks from which the Secretary sought authorization to extract Ghazal Insurance Company's bank statements.`
# WARNING: chunk-c88d25657e8fd92062fc9a4379984b7d: LLM output format error; found 3/4 feilds on ENTITY `Gulf Bank` @ `Organization<#|#>Gulf Bank is one of the banks from which the Secretary sought authorization to extract Ghazal Insurance Company's bank statements.`
# WARNING: chunk-c88d25657e8fd92062fc9a4379984b7d: LLM output format error; found 3/4 feilds on ENTITY `Boubyan Bank` @ `Organization<#|#>Boubyan Bank is one of the banks from which the Secretary sought authorization to extract Ghazal Insurance Company's bank statements.`
# WARNING: chunk-c88d25657e8fd92062fc9a4379984b7d: LLM output format error; found 3/4 feilds on ENTITY `Creditors` @ `Concept<#|#>Creditors are the parties interested in the bankruptcy proceeding whose interests the resolution states will be served by granting the Secretary's request.`
# WARNING: chunk-c88d25657e8fd92062fc9a4379984b7d: LLM output format error; found 3/4 feilds on ENTITY `Bankruptcy Estate` @ `Concept<#|#>The Bankruptcy Estate is the collection of assets subject to preservation and management in the bankruptcy proceeding and whose interests are cited as served by the authorization decision.`
# INFO: Chunk 49 of 2236 extracted 28 Ent + 25 Rel chunk-c88d25657e8fd92062fc9a4379984b7d
# INFO: Chunk 50 of 2236 extracted 14 Ent + 14 Rel chunk-12b9956937f307b6aad8fd3a35e31539
# INFO: LLM func: 4 new workers initialized (Timeouts: Func: 180s, Worker: 360s, Health Check: 375s)
# INFO: Chunk 51 of 2236 extracted 3 Ent + 3 Rel chunk-cdcfce63494eaf83372917231efe8c05
# WARNING: Cache duplication detected for default:extract:e958c8cbdeea9e30c895a1029bdcb23e, skipping update
# INFO: Chunk 52 of 2236 extracted 2 Ent + 1 Rel chunk-0f681166833ccc22bf726eaa8ba847d0
# INFO:  == LLM cache == saving: default:extract:fc35b73120852e9aa3e580905c7eb314
# INFO: Chunk 53 of 2236 extracted 2 Ent + 1 Rel chunk-e2ba4673fe0210e374bf223dd082d079
# INFO:  == LLM cache == saving: default:extract:305bed3864f3d3e4e0186c2958a41c0a
# INFO: Chunk 54 of 2236 extracted 9 Ent + 11 Rel chunk-fd959876d82fcb239beec95876471113
# INFO:  == LLM cache == saving: default:extract:da91ea069c70f565004f78fa6ac5fe99
# INFO: Chunk 55 of 2236 extracted 18 Ent + 16 Rel chunk-30f284a4495cb0bcdf695b05a6e5619b
# INFO:  == LLM cache == saving: default:extract:cfcbf598091bb1c245ce2a755b86ff0d
# INFO: Chunk 56 of 2236 extracted 7 Ent + 9 Rel chunk-81ee8015df7b9fd57f00ae38b6788c3f
# INFO:  == LLM cache == saving: default:extract:5e335efa50bf1b93381d40e965c5b3cf
# INFO:  == LLM cache == saving: default:extract:dc457921df8f8c8e1437be655dc6fe06
# INFO:  == LLM cache == saving: default:extract:e786f3172f1ba9c658a7c07dfca4fb7c
# INFO:  == LLM cache == saving: default:extract:9cecb9aa7c969e927eae1a53766544f9
# INFO:  == LLM cache == saving: default:extract:bd9fdfa75de1f0b1054c82689f3ad219
# INFO:  == LLM cache == saving: default:extract:b5ef75e8428dee29f4688ccca77f02a5
# INFO:  == LLM cache == saving: default:extract:f40b7be75e6813be41f25be2380dba05
# INFO:  == LLM cache == saving: default:extract:8de0cb8842981c820a22436c7ef77938
# INFO:  == LLM cache == saving: default:extract:3caa95191b151a1de2c2295175dff449
# INFO:  == LLM cache == saving: default:extract:79fb17619a6a3581b6bd8cef55e4bf55
# INFO:  == LLM cache == saving: default:extract:a50b0ff525b22c3b5d980ed5ad70b56a
# INFO:  == LLM cache == saving: default:extract:94db51290f94a4eb7ef3be095ac6545f
# INFO:  == LLM cache == saving: default:extract:b6893d60cbdda0db2901870b34bab975
# INFO:  == LLM cache == saving: default:extract:3865437200daaf3c26e6e308b46ae0fd
# INFO:  == LLM cache == saving: default:extract:38b01a12e542253e0bede51515002bef
# INFO:  == LLM cache == saving: default:extract:d8dfb7de6b223b4a61924f6c31553290
# INFO:  == LLM cache == saving: default:extract:bc03a2fe260639ab25468f6e18bf68ae
# INFO:  == LLM cache == saving: default:extract:c46404fce131c3fbab0ea94b9022687b
# INFO:  == LLM cache == saving: default:extract:14c1d12cb7fc202443b1c58350174724
# INFO:  == LLM cache == saving: default:extract:2ca4c68cc1ae25a2b3045fe236999cfb
# INFO:  == LLM cache == saving: default:extract:09cf1a0591df82db1a704010715a2aea
# INFO:  == LLM cache == saving: default:extract:563b4d548fa329a435646df3a3bd8c8f
# INFO:  == LLM cache == saving: default:extract:babc74762dfef6dd9766fca1966a6d04
# INFO:  == LLM cache == saving: default:extract:3ceb8d866a835f5ac04676e891aedd45
# INFO:  == LLM cache == saving: default:extract:4f250c1ddd189d9ab07438b7561ab60e
# INFO:  == LLM cache == saving: default:extract:04fb4cac3e6bc78cc80d686aa8692186
# INFO:  == LLM cache == saving: default:extract:560a25df811a6f2dbe8a8b79e9c511ba
# INFO:  == LLM cache == saving: default:extract:e9f28ad7c4466c961062905f2ccd003c
# INFO:  == LLM cache == saving: default:extract:3a7c98995a28f2fc914d0adec8e53ac1
# INFO:  == LLM cache == saving: default:extract:d5cbda1f657e45c0f271c4cbe53cb762
# INFO:  == LLM cache == saving: default:extract:0363e8e7f329bf4fa5543953fe95a27c
# INFO:  == LLM cache == saving: default:extract:ac6fe62a93ef288d994ac3a735d4fbdd
# INFO:  == LLM cache == saving: default:extract:6198018a863b3845393d9d51039e0c78
# INFO:  == LLM cache == saving: default:extract:54d8dbe92dcfdf5a85ec13b1c7c6fc31
# INFO:  == LLM cache == saving: default:extract:60119a8904166693c2ef536b14dab388
# INFO:  == LLM cache == saving: default:extract:f7cb6e92dfe2a88bea739bd88b960234
# INFO:  == LLM cache == saving: default:extract:17104295525ae5bf69569a000fd90c20
# INFO:  == LLM cache == saving: default:extract:a32c799bc1f9c7dded1921a3d764e848
# INFO:  == LLM cache == saving: default:extract:2baa01ebac9d32e135de2679a9b08a4a
# WARNING: chunk-4631a86da1de080face3c5927d2be692: LLM output format error; found 4/5 fields on REALTION `Letter No. (I_023662_2025) From the Insurance Regulation Unit (06-04-2025)`~`resignation notice, membership`
# WARNING: chunk-4631a86da1de080face3c5927d2be692: LLM output format error; found 4/5 fields on REALTION `Nomination Letter No. (MOCI_024328_2024) From the Ministry of Commerce and Industry (07-04-2025)`~`authorship, nomination`
# WARNING: chunk-4631a86da1de080face3c5927d2be692: LLM output format error; found 4/5 fields on REALTION `Nomination Letter No. (MOCI_024328_2024) From the Ministry of Commerce and Industry (07-04-2025)`~`nomination, committee membership`
# INFO:  == LLM cache == saving: default:extract:fa8aa62001fb08068bff3b0d6780a96f
# INFO:  == LLM cache == saving: default:extract:d4a356fd979ab62b34bfb0d89b9564bc
# INFO: Chunk 57 of 2236 extracted 7 Ent + 7 Rel chunk-2f9037febebe0cd614eb0ddbb1571e19
# INFO:  == LLM cache == saving: default:extract:76abe2911ce3ae6d98a71afe4c3cd0b9
# INFO: Chunk 58 of 2236 extracted 6 Ent + 6 Rel chunk-88ebe185c0bb7fcbbe3b0685dbaa47d6
# INFO:  == LLM cache == saving: default:extract:f9162b1cd7ee45a5b620225b9b7a7d09
# INFO: Chunk 59 of 2236 extracted 7 Ent + 7 Rel chunk-8eaa69b93032a3c1b32d5edefc694d48
# INFO:  == LLM cache == saving: default:extract:2c95780ab4208616f62ddd8330ea66ce
# INFO: Chunk 60 of 2236 extracted 7 Ent + 7 Rel chunk-f1773aea0df56bde71262b762c90deb4
# INFO:  == LLM cache == saving: default:extract:154d195fc6fc60739cf4694f17c69cdb
# INFO: Chunk 61 of 2236 extracted 3 Ent + 2 Rel chunk-2ac1dbcb379edf36ca71da13ca4fd9a5
# INFO:  == LLM cache == saving: default:extract:bc0dc47d16d35da2a08d5a3945fcd24e
# INFO: Chunk 62 of 2236 extracted 12 Ent + 15 Rel chunk-4c4d336feeb346ac56a11f5fee5560d8
# INFO:  == LLM cache == saving: default:extract:3b4154d7808f1610aef598d630cac1ab
# INFO: Chunk 63 of 2236 extracted 9 Ent + 12 Rel chunk-dc483a939d73fe2a877ceaa73469a4fe
# INFO:  == LLM cache == saving: default:extract:1c570016add24fc8e84a11ff00fe0857
# INFO: Chunk 64 of 2236 extracted 2 Ent + 1 Rel chunk-0d761ac73786a6493a1bd2b3faaf36ad
# INFO:  == LLM cache == saving: default:extract:6fd42bcca78bfe996507dbc52d1c2460
# INFO: Chunk 65 of 2236 extracted 9 Ent + 13 Rel chunk-4328074fe70d4fd363ab83a96023cdb5
# INFO:  == LLM cache == saving: default:extract:cfda03bfede07a432c81db288123fc46
# INFO: Chunk 66 of 2236 extracted 4 Ent + 5 Rel chunk-cb9220ff69f7ebc32a28545fe1cd4ab0
# INFO:  == LLM cache == saving: default:extract:254318d1cc915e80128567b80a49abc0
# INFO: Chunk 67 of 2236 extracted 6 Ent + 8 Rel chunk-e89a00aa2ba175dcafd0fd20798e73c1
# INFO:  == LLM cache == saving: default:extract:c85a7062d7cdf36ead16af55f424159e
# INFO: Chunk 68 of 2236 extracted 5 Ent + 4 Rel chunk-fb36171959e367c116fee80aa89ef774
# INFO:  == LLM cache == saving: default:extract:30d81afb02610c5cd83745440d3f6188
# INFO: Chunk 69 of 2236 extracted 11 Ent + 12 Rel chunk-21c8db1c7bd37eb02d2720c4ef8c85a5
# INFO:  == LLM cache == saving: default:extract:414702dd1fa6b6f531caea7480c2ab2b
# INFO: Chunk 70 of 2236 extracted 7 Ent + 6 Rel chunk-e107c6f65cebf2a5f87d77aade4fc104
# INFO:  == LLM cache == saving: default:extract:aa8101d9c4cf6dbf24ac9896e572e1f6
# INFO: Chunk 71 of 2236 extracted 6 Ent + 6 Rel chunk-9dbd936996651c9e3c0ca1c0b73d8276
# INFO:  == LLM cache == saving: default:extract:53afad279bf4ea8c7c640eaced2a5a26
# INFO: Chunk 72 of 2236 extracted 5 Ent + 6 Rel chunk-4018a22a2913727c7359cdba34140fdf
# INFO:  == LLM cache == saving: default:extract:910de1f2aab6a9a57eb6fcfac60e5a62
# INFO: Chunk 73 of 2236 extracted 18 Ent + 26 Rel chunk-98bd03f5642fd4ab61a5460bfb0dc8d6
# INFO:  == LLM cache == saving: default:extract:10cb826e028af4572408aa805f7e875b
# INFO: Chunk 74 of 2236 extracted 6 Ent + 4 Rel chunk-123a557b658da3b655100232102cc53a
# INFO:  == LLM cache == saving: default:extract:8d5707825bc8d8ad088fbe3d61e868e5
# INFO: Chunk 75 of 2236 extracted 4 Ent + 3 Rel chunk-00dee33dc7cc2b4d55aeba15747c66c7
# INFO:  == LLM cache == saving: default:extract:162f7dae76cffb4cc06a8fef81fcf0ba
# INFO: Chunk 76 of 2236 extracted 4 Ent + 3 Rel chunk-74a27f2043707a88c676f089feb88db5
# INFO:  == LLM cache == saving: default:extract:06710689c9dcdbf3be775d8b021a1df4
# INFO: Chunk 77 of 2236 extracted 11 Ent + 15 Rel chunk-76d76da7ba15acb78c2b1db8b1fff9b9
# INFO:  == LLM cache == saving: default:extract:68ef12ef4d7e2e12e567fcf62da330af
# INFO: Chunk 78 of 2236 extracted 17 Ent + 17 Rel chunk-2a13aae53cf945b8e5980a4faaa5b811
# INFO:  == LLM cache == saving: default:extract:bccf489824d8d777e9b92540dc7c59ae
# INFO: Chunk 79 of 2236 extracted 6 Ent + 7 Rel chunk-dde8e9dd91978773d2a80ff5e5484506
# INFO:  == LLM cache == saving: default:extract:4f8729f444dab1ce3eede42f15fe4d9e
# INFO: Chunk 80 of 2236 extracted 11 Ent + 13 Rel chunk-455cb771a02fdf965f72a6452a1a4b88
# INFO:  == LLM cache == saving: default:extract:0632245452d4fa7bb8ec0319ee888f10
# INFO: Chunk 81 of 2236 extracted 4 Ent + 3 Rel chunk-363364694bceac421a2d872fa6ecec75
# INFO:  == LLM cache == saving: default:extract:2296829810f9960ebc72593a64287085
# INFO: Chunk 82 of 2236 extracted 20 Ent + 25 Rel chunk-fefcda7d1d6ed40f29915710e2624623
# INFO:  == LLM cache == saving: default:extract:c042a4ad20b0c27086a669b4dc4defd4
# INFO: Chunk 83 of 2236 extracted 8 Ent + 9 Rel chunk-c7c64563038ab6d1a032ba3ae91cfc0a
# WARNING: Cache duplication detected for default:extract:d122cc1680a6f3ece1b14f166014dd7a, skipping update
# INFO: Chunk 84 of 2236 extracted 6 Ent + 6 Rel chunk-770fe56dabde5928f045abe5b8bfc6cd
# INFO:  == LLM cache == saving: default:extract:b329aeae94ef26e6717d0ec2dced1ef1
# INFO: Chunk 85 of 2236 extracted 2 Ent + 1 Rel chunk-0dffd4bf08180425bdfc79fa10b2adf2
# INFO:  == LLM cache == saving: default:extract:65f6b02d078cb8fde78ce1806f0cb780
# INFO: Chunk 86 of 2236 extracted 2 Ent + 1 Rel chunk-026f244174befa6feb5ea7fc63261f31
# INFO:  == LLM cache == saving: default:extract:1052ba56f2fe41270bf7666d9765231f
# INFO: Chunk 87 of 2236 extracted 6 Ent + 9 Rel chunk-f493669617532ab1c79b52950e6c728d
# INFO:  == LLM cache == saving: default:extract:f14e80db31a8706b2bcb86e0dbc716d5
# INFO: Chunk 88 of 2236 extracted 5 Ent + 5 Rel chunk-735fa9783035cfabf960c978cc4854e4
# INFO:  == LLM cache == saving: default:extract:b3e600deed4987234edf4d01f139b713
# INFO: Chunk 89 of 2236 extracted 5 Ent + 6 Rel chunk-a8d39df3531b863ca70254e6c2370d62
# INFO:  == LLM cache == saving: default:extract:40079400b5c5620980d04db69bda5b73
# INFO: Chunk 90 of 2236 extracted 6 Ent + 7 Rel chunk-31ed18031ffecf5e7003b4b8de10e4f9
# INFO:  == LLM cache == saving: default:extract:6d9eb877956916c3486559fb45c96075
# INFO: Chunk 91 of 2236 extracted 6 Ent + 6 Rel chunk-4970f4e8b29dfaf4db6ce96a082d1831
# INFO:  == LLM cache == saving: default:extract:17647c467f44a460776b8c9e3a121d2a
# INFO: Chunk 92 of 2236 extracted 6 Ent + 7 Rel chunk-14a1e176ff45a9c483587e02799e9e35
# INFO:  == LLM cache == saving: default:extract:e248a27ea9c2d02477368f5a621380a5
# INFO: Chunk 93 of 2236 extracted 5 Ent + 5 Rel chunk-1d95a0bef2bdb1cab1b829c675bcc276
# INFO:  == LLM cache == saving: default:extract:fed5b7ccd3fb71f6ee75a9b27bd2812a
# INFO: Chunk 94 of 2236 extracted 5 Ent + 5 Rel chunk-b0eefe3db172ff8dec85d7da81486960
# INFO:  == LLM cache == saving: default:extract:712ff7657b18b1b2d9c36e4000655687
# INFO: Chunk 95 of 2236 extracted 6 Ent + 7 Rel chunk-9d15c06c887308382e27274294557899
# INFO:  == LLM cache == saving: default:extract:93fcf8b3fc4bca678647e4b6caed07bc
# INFO:  == LLM cache == saving: default:extract:53933714fe0bff5b3170131edc13aa88
# INFO:  == LLM cache == saving: default:extract:e9561af58f2353de0228449cab0e9b22
# INFO:  == LLM cache == saving: default:extract:e084bcb3bc8f36d9402d2a3e02364228
# INFO: Chunk 96 of 2236 extracted 15 Ent + 17 Rel chunk-4631a86da1de080face3c5927d2be692
# INFO:  == LLM cache == saving: default:extract:09e6aede4efeebdc3390c86ad8773152
# INFO:  == LLM cache == saving: default:extract:3fde3bcfa8fb5e1113293428baded37f
# INFO:  == LLM cache == saving: default:extract:71404edf49a3f63c84dd130529bc03e5
# INFO:  == LLM cache == saving: default:extract:0c45bfeac12f89e030ef6a5e5d780327
# INFO:  == LLM cache == saving: default:extract:73aac284e84e3010e173e71447770733
# INFO:  == LLM cache == saving: default:extract:d85f9bd855d7e6ef8e3e9198df0d573b
# INFO:  == LLM cache == saving: default:extract:e331d05be28f0a1e13043d9004380daf
# INFO:  == LLM cache == saving: default:extract:c5256cf0a803bca2fcfaadb72d8e50a3
# INFO:  == LLM cache == saving: default:extract:4a945aaa753bbdd0d9ed6a90dab17cf1
# INFO:  == LLM cache == saving: default:extract:a3c56ad0d653675e02297a740037a1c1
# INFO:  == LLM cache == saving: default:extract:b51b8eee77ef1ab948cf7dc063d00712
# INFO:  == LLM cache == saving: default:extract:9cb245ed6648940180056bf03a08465a
# INFO:  == LLM cache == saving: default:extract:2ad80f57c81cd179d131e0ac12c84f7f
# INFO:  == LLM cache == saving: default:extract:ce7eab996107685b387d69e7c9b8100d
# INFO:  == LLM cache == saving: default:extract:429c6cf0ef19f157e4dfb862260a608b
# INFO:  == LLM cache == saving: default:extract:8c2a9c56fb8b50304c99417e6cc9bd24
# INFO:  == LLM cache == saving: default:extract:617fd9947cb58a29107c28e423160310
# INFO:  == LLM cache == saving: default:extract:230e20b5e789d9e891e8c8895bd7c9b7
# INFO:  == LLM cache == saving: default:extract:9c768bab69cb7a975c388a5eb95069e3
# INFO:  == LLM cache == saving: default:extract:1d4f74ab53961aea494887537c66300e
# INFO:  == LLM cache == saving: default:extract:0bb37eb538638fd6ba1d2dcbde4fb348
# INFO:  == LLM cache == saving: default:extract:98ee533993ed2f9e5ec1f1ade0dda902
# INFO:  == LLM cache == saving: default:extract:4127d03f05c1643de32063923f118ed8
# INFO:  == LLM cache == saving: default:extract:151a3d6e508a267edf70b85d6e5d0b38
# INFO:  == LLM cache == saving: default:extract:52fa08f04fcae08b2d3199f1f84caf16
# INFO:  == LLM cache == saving: default:extract:76fb71b3b8df39785df065369b487d87
# INFO:  == LLM cache == saving: default:extract:d785af1670cca95b76e72bfefd39d6db
# INFO:  == LLM cache == saving: default:extract:8247cbd4c7fc4a58f86eb4cc208ec43b
# INFO:  == LLM cache == saving: default:extract:cd05eaae3624f5fb6a28d5aec86da71e
# INFO:  == LLM cache == saving: default:extract:6e75b10f25d1827ba62164b4c76ef606
# INFO:  == LLM cache == saving: default:extract:3bf49ee66e281af93edb0e43be44d6c4
# INFO:  == LLM cache == saving: default:extract:779a30e744636ff5457b4613d8bdedd0
# INFO:  == LLM cache == saving: default:extract:7ee85ae752254e13a713d906394bbae1
# INFO:  == LLM cache == saving: default:extract:1f819494a41697add37daabbedb8d400
# INFO:  == LLM cache == saving: default:extract:16556b8ff9cae2b7d41fbe33e0db2a12
# INFO:  == LLM cache == saving: default:extract:a1377dff9478b9ef990f81e687d00bee
# INFO: Chunk 97 of 2236 extracted 4 Ent + 4 Rel chunk-8897d6bf2a37dfde944ec03a34d79527
# INFO:  == LLM cache == saving: default:extract:5db45a6f23a2a2f6d34a5faa97c175ee
# INFO: Chunk 98 of 2236 extracted 7 Ent + 8 Rel chunk-4b49a1f199b3ad8f923463714e676298
# INFO:  == LLM cache == saving: default:extract:26dc94e835cf465d767d60a3536c00b8
# INFO: Chunk 99 of 2236 extracted 5 Ent + 8 Rel chunk-3497c1cd3fc0290affb9d60a4f2af721
# INFO:  == LLM cache == saving: default:extract:8a79dc0629790d2c6846cbe93b4ff3aa
# INFO: Chunk 100 of 2236 extracted 6 Ent + 6 Rel chunk-e99cf64cd31f3a7d41b41924709bdaa6
# INFO:  == LLM cache == saving: default:extract:3b11f0d52837359b7289012bb6c17431
# INFO: Chunk 101 of 2236 extracted 4 Ent + 3 Rel chunk-a0603aebed1410af9f885b9c676877d7
# INFO:  == LLM cache == saving: default:extract:c0c13608a99becb78d0ec2ee3644e4ed
# INFO:  == LLM cache == saving: default:extract:6230c0d478cd983cc0cefda1ade7b48c
# INFO: Chunk 102 of 2236 extracted 6 Ent + 6 Rel chunk-fb1b0c04cb82b2b9ea571bd4eef8850b
# INFO:  == LLM cache == saving: default:extract:28b2f5103605bd0a7cb101e1bec4ac86
# INFO: Chunk 103 of 2236 extracted 11 Ent + 14 Rel chunk-83b8ae9b3269dc24595d8b1c217adc31
# INFO:  == LLM cache == saving: default:extract:ad0043007a2d8e85f64e285b8e47f68f
# INFO: Chunk 104 of 2236 extracted 9 Ent + 12 Rel chunk-c28a94eb6a6c8a8322cf6503a20aef3b
# INFO:  == LLM cache == saving: default:extract:742f135c4b600c90fa242388493d5101
# INFO: Chunk 105 of 2236 extracted 5 Ent + 5 Rel chunk-afeb47a27cf627e52a0ba8df94a02b35
# INFO:  == LLM cache == saving: default:extract:8fb9ec15ced3ff8b052aab0b5b48dded
# INFO:  == LLM cache == saving: default:extract:0d7c476bc7fd47ee2fc522592fec9247
# INFO: Chunk 106 of 2236 extracted 22 Ent + 20 Rel chunk-6ff92aee3a198dd82473eb8b1813047c
# INFO:  == LLM cache == saving: default:extract:39f1c67ec1dc33fc2c6e6dc929c7294b
# INFO: Chunk 107 of 2236 extracted 4 Ent + 4 Rel chunk-0c2b914428620231c712c5b6ab249298
# INFO:  == LLM cache == saving: default:extract:8d4eaba7189a4a874d0f821acfd4eae8
# INFO: Chunk 108 of 2236 extracted 4 Ent + 2 Rel chunk-6b820f555ab18a46771d5d9d0d4aac64
# INFO:  == LLM cache == saving: default:extract:1a051ca92809d5aebfab552f947bc44e
# INFO: Chunk 109 of 2236 extracted 7 Ent + 8 Rel chunk-99dea3576d102620a582394d498b5bc2
# INFO:  == LLM cache == saving: default:extract:3074a2ebcde570c4abfc220e9f11ff48
# INFO: Chunk 110 of 2236 extracted 5 Ent + 4 Rel chunk-2868478913e76b4d5193eb59cb6bea02
# INFO:  == LLM cache == saving: default:extract:03634540c949bf0eaba5d7178f457f9c
# INFO: Chunk 111 of 2236 extracted 4 Ent + 3 Rel chunk-3f55e9917082ccc9332cf36e45ab6ff0
# INFO:  == LLM cache == saving: default:extract:48850a960081db4e0b9057bbc090aee9
# INFO: Chunk 112 of 2236 extracted 5 Ent + 5 Rel chunk-a9a7e74c270444aba04712be0a51bb56
# INFO:  == LLM cache == saving: default:extract:619bfe596baaa3c6b72e69311c743543
# INFO: Chunk 113 of 2236 extracted 11 Ent + 12 Rel chunk-938a23622dfdd7be7a3b6e9823cadaab
# INFO:  == LLM cache == saving: default:extract:8a85930f419b70ab8f254ac01bbee303
# INFO: Chunk 114 of 2236 extracted 4 Ent + 4 Rel chunk-e78d58b5c3b526e7f9ede70529ce576d
# INFO:  == LLM cache == saving: default:extract:c1284fcbbf6c33f194ff59a9ca06bcf3
# INFO: Chunk 115 of 2236 extracted 7 Ent + 6 Rel chunk-bc29ec1662010da1f0ae9b87c55a66d8
# INFO:  == LLM cache == saving: default:extract:33c02a31754794e33e2c93ba65347d0b
# INFO: Chunk 116 of 2236 extracted 7 Ent + 7 Rel chunk-ecdbb0a6315b8429942d505697b83df4
# INFO:  == LLM cache == saving: default:extract:5eb052fcee279d41e0e026335451c139
# INFO: Chunk 117 of 2236 extracted 14 Ent + 14 Rel chunk-b9be8e9924865a45266b03362e0716ef
# INFO:  == LLM cache == saving: default:extract:040b04b58c2ec89a9b8c95b24ccc39e1
# INFO: Chunk 118 of 2236 extracted 4 Ent + 3 Rel chunk-1b8ecc36cc0581468afae08ab893763d
# INFO:  == LLM cache == saving: default:extract:3ad8ff7c31d7f69343c7e1dfc046aa55
# INFO: Chunk 119 of 2236 extracted 5 Ent + 3 Rel chunk-cc63accddabe2c1ba5dd9cce5873954a
# INFO:  == LLM cache == saving: default:extract:5633a4fad24f9c59bab4a691fc429229
# INFO: Chunk 120 of 2236 extracted 8 Ent + 7 Rel chunk-e80f9fb5aa8dff507167e49fca85dd87
# INFO:  == LLM cache == saving: default:extract:7d0a970861c10a9c71daf2a44a344dd5
# INFO: Chunk 121 of 2236 extracted 6 Ent + 6 Rel chunk-d8d41c968ec92bdfa5fa60bd8b36b00d
# INFO:  == LLM cache == saving: default:extract:565ebe4fb2e14154062177f788597e93
# INFO: Chunk 122 of 2236 extracted 8 Ent + 7 Rel chunk-e97a4e9fb4481e564bcfcc739cd0a3fa
# INFO:  == LLM cache == saving: default:extract:0df960fe4115669101bf406e51924915
# INFO: Chunk 123 of 2236 extracted 10 Ent + 12 Rel chunk-2fd0d1870243f73bc37262a602a5a489
# INFO:  == LLM cache == saving: default:extract:26b0b90600c7a77680cc98741149d407
# INFO: Chunk 124 of 2236 extracted 20 Ent + 19 Rel chunk-dd43689937e69d678ef0def55f284e05
# INFO:  == LLM cache == saving: default:extract:9c92a54cc20026be72b6c68154efa22d
# INFO: Chunk 125 of 2236 extracted 5 Ent + 4 Rel chunk-11541a163c63261867e655e64073856a
# INFO:  == LLM cache == saving: default:extract:32cd17fab2cf640f5211f5449e6c0085
# INFO: Chunk 126 of 2236 extracted 6 Ent + 4 Rel chunk-2198c10ca3fac5406dc27b989998994c
# INFO:  == LLM cache == saving: default:extract:c2100ceecd93962540b14ff9ba0d4549
# INFO: Chunk 127 of 2236 extracted 4 Ent + 4 Rel chunk-81fc19da611fd5078ed6b76230d32d8f
# INFO:  == LLM cache == saving: default:extract:0dddc10e09414e4399f8accddac530b5
# INFO: Chunk 128 of 2236 extracted 17 Ent + 17 Rel chunk-cd8ec3b7f349fdbe557ae1ecfbf165cf
# INFO:  == LLM cache == saving: default:extract:098ed7ea1f102a6ae9e588bd4b78fe8a
# INFO: Chunk 129 of 2236 extracted 12 Ent + 14 Rel chunk-0c21715903ce8f8375f82693dfdb49d7
# INFO:  == LLM cache == saving: default:extract:0ecf4bcc9329ee0cc6a27d3a26e65176
# INFO: Chunk 130 of 2236 extracted 7 Ent + 5 Rel chunk-f2094c6ed5c6b24e0b481270be7e01e8
# INFO:  == LLM cache == saving: default:extract:6147671a5af49f31523528427b7f4779
# INFO: Chunk 131 of 2236 extracted 6 Ent + 10 Rel chunk-82824c361c8e0c9f99e6c452f6e77be6
# INFO:  == LLM cache == saving: default:extract:1f92c0ce5852d928f5acff5e5e8354b8
# INFO: Chunk 132 of 2236 extracted 4 Ent + 3 Rel chunk-18cefb2fa0e9e7be146774a4ed9aaf75
# INFO:  == LLM cache == saving: default:extract:9608404eab9496c74a9e90b0a4aaea31
# INFO: Chunk 133 of 2236 extracted 6 Ent + 10 Rel chunk-564a9cb5a03f7fb61a64fc3dc098a5a1
# INFO:  == LLM cache == saving: default:extract:f9998ac5ea469ea25bcbe881b2aad00d
# INFO: Chunk 134 of 2236 extracted 12 Ent + 15 Rel chunk-9f7698e8eda7a606f8a402692f3bf705
# INFO:  == LLM cache == saving: default:extract:9e6772924aa613eab371250932c32c2b
# INFO:  == LLM cache == saving: default:extract:767df50f60a1e7437003be135193e4b2
# INFO:  == LLM cache == saving: default:extract:958697d5745627b4b0937c1ea876cf95
# INFO:  == LLM cache == saving: default:extract:eb6039ae1d8dea08d808df3f9c793512
# INFO: Chunk 135 of 2236 extracted 29 Ent + 31 Rel chunk-d2966eec629cd8b87e3674920e70dde7
# INFO:  == LLM cache == saving: default:extract:988de5dbb0acb532432c08bc96bbc5e4
# INFO:  == LLM cache == saving: default:extract:492853181f17b830ce72ef9a65bc4522
# INFO:  == LLM cache == saving: default:extract:58e91c06058b1938fcb370f500987fcd
# INFO:  == LLM cache == saving: default:extract:0f423731ffce4ba664b718a7f0356638
# INFO:  == LLM cache == saving: default:extract:0da259ad3f39c48814d62c4c3a047840
# INFO:  == LLM cache == saving: default:extract:1aa879ebea6e85cb1ad4784cc54a152b
# INFO:  == LLM cache == saving: default:extract:60ea9a0023f0da675ca2e7b4babdc61d
# INFO:  == LLM cache == saving: default:extract:39b2a93a30190f7cd49ba96987c11c2b
# INFO: Chunk 136 of 2236 extracted 39 Ent + 42 Rel chunk-7db54081df7e6d2af6614b1cc8a61d66
# INFO:  == LLM cache == saving: default:extract:e13dae9e2e657dc77592ad052e459a5b
# INFO:  == LLM cache == saving: default:extract:004fdb244f3bef89f3c22c1f8e736c84
# INFO:  == LLM cache == saving: default:extract:e79be421bdc54e12012c6d571f68141d
# INFO:  == LLM cache == saving: default:extract:0432e3a3aa0ec13bdab5052b3863db69
# INFO:  == LLM cache == saving: default:extract:41f99a2dbae5a656aa836064f983f25d
# INFO:  == LLM cache == saving: default:extract:d425e265b34cd68c4e77486219067c8f
# INFO:  == LLM cache == saving: default:extract:673d303456c7bb95e98af9f292966e63
# INFO:  == LLM cache == saving: default:extract:1ae78ca04f66ac63011efcbd4c9a9cc1
# INFO:  == LLM cache == saving: default:extract:893de51dac022631ccb9d14fb95bedca
# INFO:  == LLM cache == saving: default:extract:877334bab020691bb94cc12fd718baab
# INFO:  == LLM cache == saving: default:extract:fa9de8c7b70792a3e2b102b20cf2433f
# INFO:  == LLM cache == saving: default:extract:318f3c5594c1d92463e648d79d38d7a5
# INFO:  == LLM cache == saving: default:extract:43c6e8908d10c5a7e9d079e63d785e75
# INFO:  == LLM cache == saving: default:extract:4529a418f27b8d24c0b297fe901ef48b
# INFO:  == LLM cache == saving: default:extract:01a7b44cb731b61ed45806d386569df8
# INFO:  == LLM cache == saving: default:extract:154a4a7ce23eb2f3d2c6c2ab294eec43
# INFO:  == LLM cache == saving: default:extract:d109645b547044b844521586eb949065
# INFO:  == LLM cache == saving: default:extract:287c953c4f93885d99b66db4e858d5c1
# INFO:  == LLM cache == saving: default:extract:ef61ee7f674e504656fb0b82df74fd63
# INFO: Enqueued document processing pipeline stopped
# LightRAG ingest:   0%|          | 0/10 [33:09<?, ?file/s]
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[2], line 32
#      29 rag = build_lightrag()
#      30 await ensure_initialized(rag)
# ---> 32 ingested = await ingest_markdown_files(
#      33     rag,
#      34     source_dir=source_dir,
#      35     max_workers=MAX_WORKERS,
#      36     show_progress=True,
#      37     show_chunk_progress=True,
#      38     chunking=chunk_cfg,
#      39     fallback=fallback_cfg,
#      40 )
#      42 print(f"Ingested {len(ingested)} markdown files from {source_dir}.")
#
# File /mnt/c/Users/sepeh/OneDrive/Documents/Git/GraphRag_Developer_Challenge3/KnowledgeGraph/LightRAG/lightrag_runner.py:579, in ingest_markdown_files(rag, source_dir, split_by_character, split_by_character_only, max_workers, show_progress, show_chunk_progress, chunking, fallback)
#     576         actual_split_only = True
#     578     with _chunk_progress_manager(show_chunk_progress, fallback_state):
# --> 579         await rag.ainsert(
#     580             input=input_text,
#     581             ids=doc_id,
#     582             file_paths=str(path.name),
#     583             split_by_character=actual_split,
#     584             split_by_character_only=actual_split_only,
#     585         )
#     586     ingested.append(path)
#     588 if fallback_state:
#
# File ~/.cache/pypoetry/virtualenvs/graphrag-developer-challenge3-4suqu0LP-py3.12/lib/python3.12/site-packages/lightrag/lightrag.py:1132, in LightRAG.ainsert(self, input, split_by_character, split_by_character_only, ids, file_paths, track_id)
#    1129     track_id = generate_track_id("insert")
#    1131 await self.apipeline_enqueue_documents(input, ids, file_paths, track_id)
# -> 1132 await self.apipeline_process_enqueue_documents(
#    1133     split_by_character, split_by_character_only
#    1134 )
#    1136 return track_id
#
# File ~/.cache/pypoetry/virtualenvs/graphrag-developer-challenge3-4suqu0LP-py3.12/lib/python3.12/site-packages/lightrag/lightrag.py:2050, in LightRAG.apipeline_process_enqueue_documents(self, split_by_character, split_by_character_only)
#    2048 # Wait for all document processing to complete
#    2049 try:
# -> 2050     await asyncio.gather(*doc_tasks)
#    2051 except PipelineCancelledException:
#    2052     # Cancel all remaining tasks
#    2053     for task in doc_tasks:
#
# File ~/.cache/pypoetry/virtualenvs/graphrag-developer-challenge3-4suqu0LP-py3.12/lib/python3.12/site-packages/lightrag/lightrag.py:1838, in LightRAG.apipeline_process_enqueue_documents.<locals>.process_document(doc_id, status_doc, split_by_character, split_by_character_only, pipeline_status, pipeline_status_lock, semaphore)
#    1832     # Stage 2: Process entity relation graph (after text_chunks are saved)
#    1833     entity_relation_task = asyncio.create_task(
#    1834         self._process_extract_entities(
#    1835             chunks, pipeline_status, pipeline_status_lock
#    1836         )
#    1837     )
# -> 1838     chunk_results = await entity_relation_task
#    1839     file_extraction_stage_ok = True
#    1841 except Exception as e:
#    1842     # Check if this is a user cancellation
#
# File ~/.cache/pypoetry/virtualenvs/graphrag-developer-challenge3-4suqu0LP-py3.12/lib/python3.12/site-packages/lightrag/lightrag.py:2107, in LightRAG._process_extract_entities(self, chunk, pipeline_status, pipeline_status_lock)
#    2103 async def _process_extract_entities(
#    2104     self, chunk: dict[str, Any], pipeline_status=None, pipeline_status_lock=None
#    2105 ) -> list:
#    2106     try:
# -> 2107         chunk_results = await extract_entities(
#    2108             chunk,
#    2109             global_config=asdict(self),
#    2110             pipeline_status=pipeline_status,
#    2111             pipeline_status_lock=pipeline_status_lock,
#    2112             llm_response_cache=self.llm_response_cache,
#    2113             text_chunks_storage=self.text_chunks,
#    2114         )
#    2115         return chunk_results
#    2116     except Exception as e:
#
# File ~/.cache/pypoetry/virtualenvs/graphrag-developer-challenge3-4suqu0LP-py3.12/lib/python3.12/site-packages/lightrag/operate.py:2945, in extract_entities(chunks, global_config, pipeline_status, pipeline_status_lock, llm_response_cache, text_chunks_storage)
#    2941     tasks.append(task)
#    2943 # Wait for tasks to complete or for the first exception to occur
#    2944 # This allows us to cancel remaining tasks if any task fails
# -> 2945 done, pending = await asyncio.wait(tasks, return_when=asyncio.FIRST_EXCEPTION)
#    2947 # Check if any task raised an exception and ensure all exceptions are retrieved
#    2948 first_exception = None
#
# File /usr/lib/python3.12/asyncio/tasks.py:464, in wait(fs, timeout, return_when)
#     461     raise TypeError("Passing coroutines is forbidden, use tasks explicitly.")
#     463 loop = events.get_running_loop()
# --> 464 return await _wait(fs, timeout, return_when, loop)
#
# File /usr/lib/python3.12/asyncio/tasks.py:550, in _wait(fs, timeout, return_when, loop)
#     547     f.add_done_callback(_on_completion)
#     549 try:
# --> 550     await waiter
#     551 finally:
#     552     if timeout_handle is not None:
#
# CancelledError:
# INFO:  == LLM cache == saving: default:extract:773b22c02cca8b6abb393925ee326b20
# INFO:  == LLM cache == saving: default:extract:2339c444c0ba476ec7c463d65dfc204d
# INFO:  == LLM cache == saving: default:extract:661c6c5405622e5abe8ae68c2773bc3f
# INFO:  == LLM cache == saving: default:extract:5fe1a8e79741caf31d29a8da1d334f20
# INFO:  == LLM cache == saving: default:extract:49b05be77fa3c07291d42a2f6c01f27d
# INFO:  == LLM cache == saving: default:extract:1e1fa77ff4b411d9fa41366a58ab3dd9
# INFO:  == LLM cache == saving: default:extract:7ca6d62f40746a543d3e9d2315d2bb02
# INFO:  == LLM cache == saving: default:extract:48fd1d3b9aa48c031f6da0a15c459a58
# WARNING: chunk-0cd75dec8c93b356e9bb4758e4b794d5: LLM output format error; found 4/5 fields on REALTION `Decision No. 72/2025`~`15-Year Upfront Payment Rate<#|#>tariff structure,payment terms`
# INFO:  == LLM cache == saving: default:extract:c971bffc556ab08c7bf1d5c39b34195c
# INFO: Chunk 137 of 2236 extracted 21 Ent + 19 Rel chunk-55180b13e8b026de267158d77de89b61
# INFO:  == LLM cache == saving: default:extract:56b31872a2bf46b1bc8391700ba2ff46
# INFO: Chunk 138 of 2236 extracted 5 Ent + 5 Rel chunk-5ba83b28eabb1bee14c449ddea86e330
# INFO:  == LLM cache == saving: default:extract:2e3bffb9ff7e9cef33261fcba67b229a
# INFO: Chunk 139 of 2236 extracted 21 Ent + 21 Rel chunk-595b4a79a7bc8931a9b8dae02a5e0769
# INFO:  == LLM cache == saving: default:extract:5e6b40b9166ae62d8c03e1f2c761dcff
# INFO:  == LLM cache == saving: default:extract:3ab08cad958b91a81c28c0fd44d2929d
# INFO:  == LLM cache == saving: default:extract:615afc77ca671b687a9587adc861b7aa
# INFO: Chunk 140 of 2236 extracted 3 Ent + 2 Rel chunk-f912ec1b2137b79fa19ea9b01b594dfe
# INFO:  == LLM cache == saving: default:extract:32e7680a9f2226de14f4372855f253b3
# INFO: Chunk 141 of 2236 extracted 35 Ent + 31 Rel chunk-3515aa96e3f4966a31946b30f790afdb
# INFO:  == LLM cache == saving: default:extract:bda1fe05b36c7f195dc8b233a1c4f2ca
# INFO: Chunk 142 of 2236 extracted 25 Ent + 21 Rel chunk-cfae9c205716e7d1790dcfc8abf9a68c
# INFO:  == LLM cache == saving: default:extract:2b4e6f87ab7102170981ec1d5143f2c1
# INFO: Chunk 143 of 2236 extracted 4 Ent + 4 Rel chunk-f2ab32fb52c846dcfc321003ac7fd5ae
# INFO:  == LLM cache == saving: default:extract:c0ee3ee49fa14f4f209bbce07e3f0b10
# INFO: Chunk 144 of 2236 extracted 18 Ent + 16 Rel chunk-96f24907339749f2e48aa7e1e8c71c9e
# INFO:  == LLM cache == saving: default:extract:b81898e8218518f2fac87d5c6a80ed1c
# INFO: Chunk 145 of 2236 extracted 22 Ent + 22 Rel chunk-b365b275a2b916358b3a99e154769cdf
# INFO:  == LLM cache == saving: default:extract:a4fa891b8c3bef69da926d31e28939df
# INFO: Chunk 146 of 2236 extracted 3 Ent + 1 Rel chunk-7fb644ad61d4f473854b8f8b8c7ea5a2
# INFO:  == LLM cache == saving: default:extract:2903ead803e3f43a696ee2081ea38e82
# INFO: Chunk 147 of 2236 extracted 3 Ent + 1 Rel chunk-c90527e31507ac4b73c6d5c8099a033f
# INFO:  == LLM cache == saving: default:extract:db5924669c3f3bd69ee07ec233e1e607
# INFO: Chunk 148 of 2236 extracted 3 Ent + 2 Rel chunk-236496d8c7e411cad5ffc1f22ef43061
# INFO:  == LLM cache == saving: default:extract:8f86b7cf68ce1e7fec9943d45b59e51a
# INFO: Chunk 149 of 2236 extracted 14 Ent + 14 Rel chunk-bf6e7d5e5923c8246df5290c61a6723d
# INFO:  == LLM cache == saving: default:extract:3a2beac657f0cad7e484ae397f9c5c7c
# INFO: Chunk 150 of 2236 extracted 21 Ent + 23 Rel chunk-05cdd7cbbc311163d8e65b66db99cd7f
# INFO:  == LLM cache == saving: default:extract:68ee7969c80892a3cb4305a680497909
# INFO:  == LLM cache == saving: default:extract:fd8df2ee8f63bdb133c43ceed43723e1
# INFO: Chunk 151 of 2236 extracted 4 Ent + 4 Rel chunk-576ebc21f888724e1e05a8f9dfe7ef97
# INFO:  == LLM cache == saving: default:extract:702cf64ea7ca8e68e21d6a21b93ae31c
# INFO: Chunk 152 of 2236 extracted 16 Ent + 16 Rel chunk-e7d50b62914dcdadb12a892bf4bc64aa
# INFO:  == LLM cache == saving: default:extract:3c70f0142ba36d29b0f41c5d1c33343c
# INFO: Chunk 153 of 2236 extracted 3 Ent + 1 Rel chunk-273833ed2db649e1e1400ac6ce44ff23
# INFO:  == LLM cache == saving: default:extract:966f673f24923231496d02522dad90b9
# INFO: Chunk 154 of 2236 extracted 6 Ent + 6 Rel chunk-4dba46875bfb711fd2e6577ac4d9ea66
# INFO:  == LLM cache == saving: default:extract:9655ad81046add93b91e5013885b4888
# INFO: Chunk 155 of 2236 extracted 4 Ent + 2 Rel chunk-c9ef33b9d9b7651a38fc281aa8ca1502
# INFO:  == LLM cache == saving: default:extract:c6d3955036f136951f0fd337fadf45e0
# INFO: Chunk 156 of 2236 extracted 3 Ent + 2 Rel chunk-fe55fccdf0604a2e5ccaff1359d3338c
# INFO:  == LLM cache == saving: default:extract:c98fa99361758c324246e088f0f3f1cd
# INFO: Chunk 157 of 2236 extracted 4 Ent + 4 Rel chunk-930ba4e51f6eae7a119349ab9ece4354
# INFO:  == LLM cache == saving: default:extract:cd2bb9b12fd45a78f7d5894a5887a747
# INFO: Chunk 158 of 2236 extracted 3 Ent + 2 Rel chunk-d1ae9610ddac8264c75750ac7c8bd067
# INFO:  == LLM cache == saving: default:extract:32f9eff1ff9e1c37710ba3a405c2544a
# INFO: Chunk 159 of 2236 extracted 3 Ent + 2 Rel chunk-d464dd330eb96a7350a52044fe8bbb3a
# INFO:  == LLM cache == saving: default:extract:9e82c63d68ee286e79463ee0bfd4d36b
# INFO: Chunk 160 of 2236 extracted 4 Ent + 4 Rel chunk-a508f7a7f411a610ae3f0033d4b6faa5
# INFO:  == LLM cache == saving: default:extract:d8d707f324f1737418bec67a023aac90
# INFO: Chunk 161 of 2236 extracted 8 Ent + 9 Rel chunk-6b86e0ee99a322dc8fbc3489b7b209c8
# INFO:  == LLM cache == saving: default:extract:af5cc7d72637c01c475e07b75671d8ba
# INFO: Chunk 162 of 2236 extracted 6 Ent + 4 Rel chunk-6a6987d64fb3a693e0b3f8e35f80a331
# INFO:  == LLM cache == saving: default:extract:4c092661d8e7d1ec17749fa04cd9ddb7
# INFO: Chunk 163 of 2236 extracted 15 Ent + 15 Rel chunk-8007964458858b8c80a9a9458cfb1f47
# INFO:  == LLM cache == saving: default:extract:5aa0ec31590db6a8a684068f04539a01
# INFO: Chunk 164 of 2236 extracted 4 Ent + 4 Rel chunk-853dd36eb848efd94db4df61e369319b
# INFO:  == LLM cache == saving: default:extract:49b8835db22a0bc788f21ea975cf9681
# INFO: Chunk 165 of 2236 extracted 4 Ent + 4 Rel chunk-e0feb66e71ddc693adfa73921bc57849
# INFO:  == LLM cache == saving: default:extract:80eaf1c9fb70cc3c7b1f755967a83880
# INFO: Chunk 166 of 2236 extracted 19 Ent + 23 Rel chunk-1b91a510c59388b88d640ac50c958694
# INFO:  == LLM cache == saving: default:extract:b1e0fbde7b46d8f24c17e97e1524f9cc
# INFO: Chunk 167 of 2236 extracted 5 Ent + 7 Rel chunk-cc472442a66c5f9eb2aa76e3a3bbb3f9
# INFO:  == LLM cache == saving: default:extract:c0b694d8bc44fd52f3eef9d6e3bc711f
# INFO: Chunk 168 of 2236 extracted 3 Ent + 2 Rel chunk-612115a0570127cf069e0d54721d5615
# INFO:  == LLM cache == saving: default:extract:9fe5115306bb162667bb8b1b9bff4274
# INFO: Chunk 169 of 2236 extracted 5 Ent + 7 Rel chunk-2dab9c037fa2636be158d931819af745
# INFO:  == LLM cache == saving: default:extract:c1d1dcfe7e2d00dabba33009bcdb3e62
# INFO: Chunk 170 of 2236 extracted 4 Ent + 4 Rel chunk-891aa735df605e82e718de3ad723d891
# INFO:  == LLM cache == saving: default:extract:eeff315cc434351dc597c6d38c67251a
# INFO: Chunk 171 of 2236 extracted 7 Ent + 8 Rel chunk-64d7b2925128d02a5d3b9a648cfeb4ba
# INFO:  == LLM cache == saving: default:extract:73ef51013d7e1f7e4e4bd19998636c0e
# INFO: Chunk 172 of 2236 extracted 19 Ent + 19 Rel chunk-0cd75dec8c93b356e9bb4758e4b794d5
# INFO:  == LLM cache == saving: default:extract:d593ef34b409abdb5819f333d8360571
# INFO: Chunk 173 of 2236 extracted 6 Ent + 9 Rel chunk-7155475dcf821ee4ea22ae5b28d6a047
# INFO:  == LLM cache == saving: default:extract:3ff0ab84003a26125c32d9abdee57cea
# INFO: Chunk 174 of 2236 extracted 5 Ent + 4 Rel chunk-1f64b4986f7c57dea7d5c94824edb5ca
# INFO:  == LLM cache == saving: default:extract:c87bfe668ff92589ed3268b35bb8c615
# INFO:  == LLM cache == saving: default:extract:67f42b47ba8679f2aed538ddfc8bb012
# INFO:  == LLM cache == saving: default:extract:585cc14552a1cb00e3a589f1a08187ff
# INFO:  == LLM cache == saving: default:extract:94a0e670a8d664dfc079685f549d2027
# INFO:  == LLM cache == saving: default:extract:8e8f0aaa03dcff101927aee484fbc48f
# INFO:  == LLM cache == saving: default:extract:909fffca826b6ebe26964d6fad6d6e26
# INFO: Chunk 175 of 2236 extracted 17 Ent + 22 Rel chunk-fe48e357e792f362dffaa7d3af5f5a1a
# INFO:  == LLM cache == saving: default:extract:217c9e6380bd998cadb6f3b1d245de17
# INFO:  == LLM cache == saving: default:extract:6acc14bc5b17f5cc0596656df8d25661
# INFO:  == LLM cache == saving: default:extract:6f1d5105f87489f664888c6211ba56cb
# INFO:  == LLM cache == saving: default:extract:47be77c72430ded05dfe4d338fa09bd9
# INFO:  == LLM cache == saving: default:extract:b82036632f96a31a55a091fab18b3bbf
# INFO:  == LLM cache == saving: default:extract:dece93416fd3094794cf3f93fa1a69c9
# INFO:  == LLM cache == saving: default:extract:8cee0a9ecb3cdc409669be1d51d7b974
# INFO:  == LLM cache == saving: default:extract:569e7caca2fb09eac1607018c4accf78
# INFO:  == LLM cache == saving: default:extract:0d85c5d32d49e980e4646c56648a094f
# INFO: Chunk 176 of 2236 extracted 7 Ent + 10 Rel chunk-d5635109c3bbb6b11c813d655544b548
# INFO:  == LLM cache == saving: default:extract:6f8864dcbd1c5d985f49c508a6fe13a9
# INFO:  == LLM cache == saving: default:extract:e96d31e6275863e3a0e201a2417a3259
# INFO:  == LLM cache == saving: default:extract:52b730c9a92e5bfa7bb9e88bacd4c443
# INFO:  == LLM cache == saving: default:extract:7ce6b79ec17862522c102f7ce12c21b6
# INFO:  == LLM cache == saving: default:extract:c803ba7191e04fe62de61e0498e61eda
# INFO:  == LLM cache == saving: default:extract:ea5d5887440c1e351f935c8cab47d0b8
# INFO:  == LLM cache == saving: default:extract:348bfdbefc9f7fc16af61069d8f05a00
# INFO:  == LLM cache == saving: default:extract:114c736c5bcddc2fefacd7a9803c6afd
# INFO:  == LLM cache == saving: default:extract:9c2e1fe49728e4bbd15fb22c09545ce3
# INFO:  == LLM cache == saving: default:extract:f2a0277f65a14038b9abf23b05482898
# INFO:  == LLM cache == saving: default:extract:f20b3c943fb17a0c81cea84401f5c30a
# INFO:  == LLM cache == saving: default:extract:614bb23431b649db3babfcd1f279b0b3
# INFO:  == LLM cache == saving: default:extract:b2fd4f613d80f17f496bf2d9f083c220
# INFO:  == LLM cache == saving: default:extract:90b38d0d577c273fde9b67f369bbe232
# INFO:  == LLM cache == saving: default:extract:082c79aaea78d1019224948ed87e5504
# INFO:  == LLM cache == saving: default:extract:95a2c905e373d47a2e33b0fb85fad86c
# INFO:  == LLM cache == saving: default:extract:3b46090cd5155887003c0cd0a26a5290
# INFO:  == LLM cache == saving: default:extract:8184392df5339e1ffb358b9e8b2b55fb
# INFO:  == LLM cache == saving: default:extract:acdffe405b9fdbd70116bb4b35568290
# INFO:  == LLM cache == saving: default:extract:5e23437cbfe8cc4188d4e5472c6e2be0
# INFO:  == LLM cache == saving: default:extract:b06c3eb1d09c3d640c11b1fbeb37adc9
# INFO:  == LLM cache == saving: default:extract:ae8b93e76437bcc2e5c3462bfb1e5578
# INFO:  == LLM cache == saving: default:extract:89b90b34ac822d722b1de2187d3499ec
# INFO:  == LLM cache == saving: default:extract:5cc91a58eeffda8caf3f9179a022a02e
# INFO:  == LLM cache == saving: default:extract:cb15e20fec262b5a00a881985a4a8409
# ...
# INFO:  == LLM cache == saving: default:extract:691702264ee667c49adda62065361ff6
# INFO: Chunk 1250 of 2236 extracted 17 Ent + 17 Rel chunk-0a84aa6ac717773f94b41c84df56e706
# INFO:  == LLM cache == saving: default:extract:87a7028ab222ec1db4bb7afa17f938f1
# INFO: Chunk 1251 of 2236 extracted 8 Ent + 9 Rel chunk-24871328ebad9e0d8c9a131eeee8b157
# INFO:  == LLM cache == saving: default:extract:130c4da3dbcfc8631017d7e5d83ff83b
# INFO: Chunk 1252 of 2236 extracted 9 Ent + 11 Rel chunk-b932e866baf6e1704f7fd41bf7011859
# INFO:  == LLM cache == saving: default:extract:e1d65323655930cd76faeb3bc271e014
# INFO:  == LLM cache == saving: default:extract:080021f4821c3b3a09f5257641357375
# INFO:  == LLM cache == saving: default:extract:a2fc49140189d54688fa02f350839f25
# INFO:  == LLM cache == saving: default:extract:5743f0c9436395a94cf19d1b9eb56caa
# INFO:  == LLM cache == saving: default:extract:49ec8af68bb9335f4fd2fcacb732b7f8
# INFO:  == LLM cache == saving: default:extract:c68b32e0edecfdac2da4fcf7fc2f2f93
# INFO: Chunk 1253 of 2236 extracted 7 Ent + 8 Rel chunk-c79bc25cae22522d4bcb5c77ecf56e93
# INFO:  == LLM cache == saving: default:extract:8de7562e4c6ff2aa4ef2d95c323abdee
# INFO:  == LLM cache == saving: default:extract:a310e5f7b88474772bd796a078f3b5c5
# INFO:  == LLM cache == saving: default:extract:4859d02aabb7105cb091e7b8b478efd1
# INFO:  == LLM cache == saving: default:extract:4421e008bd1aa9f3e19999ff312adcbb
# INFO:  == LLM cache == saving: default:extract:be6e18ac42ba6d0cbda736fb3f62139b
# INFO:  == LLM cache == saving: default:extract:d092d2f00574a10a44f25965b7d0f14d
# INFO:  == LLM cache == saving: default:extract:99957a9b01789594e7ce4e7b34891fe6
# INFO:  == LLM cache == saving: default:extract:15bc00f1103c8c771845625b4bf2bf48
# INFO:  == LLM cache == saving: default:extract:a879ada64bdfa5335f63e886174c66ad
# INFO:  == LLM cache == saving: default:extract:1e23a99ab114a44726e5522480acf9a1
# INFO:  == LLM cache == saving: default:extract:ae509d7fd4112ff2de0d5699147538ec
# INFO:  == LLM cache == saving: default:extract:3340d72d66c0bb298ef927f3762027f8
# INFO:  == LLM cache == saving: default:extract:c88b4da4d306ea9e01a08becb8d12dee
# INFO: Chunk 1254 of 2236 extracted 92 Ent + 133 Rel chunk-0518ab5bcb49f509d652b0c6a2697eb6
# INFO:  == LLM cache == saving: default:extract:3dc156a6de885dcfac377e594be2a842
# INFO:  == LLM cache == saving: default:extract:bd6d57ca12ab937e2417639ec55e9cf5
# INFO:  == LLM cache == saving: default:extract:abf2821664bb24551606ff85947b0aad
# INFO: Chunk 1255 of 2236 extracted 10 Ent + 17 Rel chunk-d8a344fb4b2bb46cabf26108d49c6c87
# INFO:  == LLM cache == saving: default:extract:758c091fd9439d743370f1842a846f3b
# INFO: Chunk 1256 of 2236 extracted 14 Ent + 20 Rel chunk-f834431e709d5fb50179b6ff4eb57e7a
# INFO:  == LLM cache == saving: default:extract:b2da3cb7cde8753f8e330bbca2c131a9
# INFO: Chunk 1257 of 2236 extracted 23 Ent + 20 Rel chunk-9d1e9461bb92df1c22825900d29214d2
# INFO:  == LLM cache == saving: default:extract:d85f5d0335550e80aee12f2ba54fe3cf
# INFO:  == LLM cache == saving: default:extract:5f2310ce77d3815c174d5f589732116f
# INFO:  == LLM cache == saving: default:extract:ece09ce9fe253a736af83498d03d26bb
# INFO:  == LLM cache == saving: default:extract:30584dbe638550e142739fbc02c9c94d
# INFO: Chunk 1258 of 2236 extracted 15 Ent + 16 Rel chunk-b38608b45ab4e264df5f822cd979ccf1
# INFO:  == LLM cache == saving: default:extract:fc4cb19a98774b734ac1e362c23a3b8c
# INFO:  == LLM cache == saving: default:extract:6c9ecf83331869b704769dc1e143f57a
# INFO:  == LLM cache == saving: default:extract:dd7475e16a1fcb81c96d3b3d219d2a16
# INFO:  == LLM cache == saving: default:extract:af9f495ccf553eb908bea39124639e32
# INFO:  == LLM cache == saving: default:extract:512b91eebabd2636c6af8f15c35ed46d
# INFO: Chunk 1259 of 2236 extracted 8 Ent + 14 Rel chunk-80cc990408e0fbe349b15a021380d961
# INFO:  == LLM cache == saving: default:extract:6bf7b938c2c196f5601ef2ebef42d6f2
# INFO:  == LLM cache == saving: default:extract:0aa223e2e006d03239e2a155a278a75f
# INFO: Chunk 1260 of 2236 extracted 14 Ent + 16 Rel chunk-50afd545ac158ed05e1ed03d13a4b5e7
# INFO:  == LLM cache == saving: default:extract:97bd0cefb9055f340003970589b04212
# INFO: Chunk 1261 of 2236 extracted 12 Ent + 18 Rel chunk-24f0ba1e503d56593079923bdd734f7c
# INFO:  == LLM cache == saving: default:extract:f76ae35f5e76e06dc249b4b551fe9aee
# INFO:  == LLM cache == saving: default:extract:3b45c43d4e886101158cb450b8f31b66
# INFO: Chunk 1262 of 2236 extracted 2 Ent + 1 Rel chunk-62c759a996dbf3651b99e213fa4dc9c3
# INFO:  == LLM cache == saving: default:extract:32d4d34eea68f2cf6885c2f65dd133e3
# INFO:  == LLM cache == saving: default:extract:7c01d96b64c2847781630263ba43f57d
# INFO:  == LLM cache == saving: default:extract:e33925225bcb324641e844d244e5d836
# INFO:  == LLM cache == saving: default:extract:d5d79e233f340c6f5fee70bce1861b16
# INFO: Chunk 1263 of 2236 extracted 9 Ent + 12 Rel chunk-6e05083988e29d4335c50daaf7d8f451
# INFO:  == LLM cache == saving: default:extract:0d47f3b08f51f3c3d3697ece5a14202b
# INFO: Chunk 1264 of 2236 extracted 8 Ent + 9 Rel chunk-0215013d31475a077656be2390bc99f4
# INFO:  == LLM cache == saving: default:extract:00f59043018b8545b962c2d52e34d16e
# INFO: Chunk 1265 of 2236 extracted 16 Ent + 19 Rel chunk-8d931b54495f5dbe45014aafadf4c656
# INFO:  == LLM cache == saving: default:extract:64201f8eda0aba089484610fca903efb
# INFO: Chunk 1266 of 2236 extracted 11 Ent + 12 Rel chunk-1dec05226f470f5f8c18752908b97259
# INFO:  == LLM cache == saving: default:extract:7053c4e554151c653ae56e5382ca776c
# INFO: Chunk 1267 of 2236 extracted 8 Ent + 10 Rel chunk-bac689232a11b181ea5984502995c252
# INFO:  == LLM cache == saving: default:extract:ce5c6c2a97ff6fd85669e525fd59411b
# INFO:  == LLM cache == saving: default:extract:229da21d6777237f3fbecf15d52cbf8c
# INFO: Chunk 1268 of 2236 extracted 11 Ent + 12 Rel chunk-8ed7eb9143808fb330fae5c1fb74bc46
# INFO:  == LLM cache == saving: default:extract:b7e0859615cbb9aefdd05376da265d8a
# INFO: Chunk 1269 of 2236 extracted 9 Ent + 10 Rel chunk-e44edd01c966c65185d2660953181f72
# INFO:  == LLM cache == saving: default:extract:2cc5d337258da1867091fb4cdd7f3b93
# INFO: Chunk 1270 of 2236 extracted 10 Ent + 11 Rel chunk-0a39f3b3d5e5f77167defe6a0da33742
# INFO:  == LLM cache == saving: default:extract:e5eb83d4187f7f67664467add0072a70
# INFO: Chunk 1271 of 2236 extracted 9 Ent + 13 Rel chunk-0bf706c0669cc1cd23ba42277e22800d
# INFO:  == LLM cache == saving: default:extract:419b664b506b9a87e966f88dcc621cd4
# INFO: Chunk 1272 of 2236 extracted 7 Ent + 6 Rel chunk-74f5dd90d6bbc1e9d95d8f464b60633c
# INFO:  == LLM cache == saving: default:extract:906c45b42ad1b11a41a76d11c3f0400a
# INFO: Chunk 1273 of 2236 extracted 15 Ent + 19 Rel chunk-e1b47b7bac144e3f7779260fa5fedf7f
# INFO:  == LLM cache == saving: default:extract:4c464e61e00130da0e8618e1d30d9a09
# INFO: Chunk 1274 of 2236 extracted 17 Ent + 21 Rel chunk-89ace74aed3f1ba6c13b64f4595ae0e6
# INFO:  == LLM cache == saving: default:extract:62013ef55303fe5144db7cb31b7ed617
# INFO: Chunk 1275 of 2236 extracted 13 Ent + 18 Rel chunk-b4b8336ad2c71a590cc6280f62692489
# INFO:  == LLM cache == saving: default:extract:0044fc4242e817773a6cbe36b5282783
# INFO: Chunk 1276 of 2236 extracted 11 Ent + 13 Rel chunk-75965be86d9a6f367f8455bb345e56eb
# INFO:  == LLM cache == saving: default:extract:397bb63f012fa5fab9cb5d5e96e55ee4
# INFO:  == LLM cache == saving: default:extract:32e25df122be5c0d940300d41fd39670
# INFO: Chunk 1277 of 2236 extracted 20 Ent + 24 Rel chunk-2baa0900191921fd92bf9505176a31dc
# INFO:  == LLM cache == saving: default:extract:9e653e4330fb21b82d7e3ceb8ce192a8
# INFO: Chunk 1278 of 2236 extracted 22 Ent + 21 Rel chunk-9bcaca26d4d4c47bc1323c0e6b7d92ed
# INFO:  == LLM cache == saving: default:extract:a22baad929999b9a52357f49367a34dc
# INFO: Chunk 1279 of 2236 extracted 8 Ent + 10 Rel chunk-278f00c900ea1c039708e423acf547c3
# INFO:  == LLM cache == saving: default:extract:c265b85d9e08621e9885eca9071c8991
# INFO: Chunk 1280 of 2236 extracted 14 Ent + 15 Rel chunk-92f14f9456b5b921f7c1bbc1b87a48fa
# INFO:  == LLM cache == saving: default:extract:62d2695e50df0f582bbb8daecb6b549e
# INFO:  == LLM cache == saving: default:extract:dd5b469bb76cedc92d7d41e76d6cb8af
# INFO:  == LLM cache == saving: default:extract:10475dea4c52f253e7ed27f55bf75fc7
# INFO:  == LLM cache == saving: default:extract:404cdf6078debfa423b29d238478862e
# INFO: Chunk 1281 of 2236 extracted 23 Ent + 23 Rel chunk-6ab64af7c5ef5c739d36c6e2f9d1a833
# INFO:  == LLM cache == saving: default:extract:ac5e8faffa7c339e8005a1a20659deb7
# INFO: Chunk 1282 of 2236 extracted 8 Ent + 8 Rel chunk-941ccfd6e7fbf1c64d3e547d471c2c8f
# INFO:  == LLM cache == saving: default:extract:9263f5f3c15fdcc1dc624d6256d9a4d7
# INFO: Chunk 1283 of 2236 extracted 7 Ent + 6 Rel chunk-cee28ac8ca9e7a7ab0cb4fb8a038d756
# INFO:  == LLM cache == saving: default:extract:630efb898210af73f84e6b8937c72db3
# INFO: Chunk 1284 of 2236 extracted 10 Ent + 9 Rel chunk-6894b6d3abb1edb3c452c41f0868bfdc
# INFO:  == LLM cache == saving: default:extract:8995122ba005bb40df6685946f7ece30
# INFO: Chunk 1285 of 2236 extracted 17 Ent + 16 Rel chunk-7980c298590f507d29c2204d980b5145
# INFO:  == LLM cache == saving: default:extract:5b419191554a92b7c959a8dd8a0de79e
# INFO:  == LLM cache == saving: default:extract:ab9fd45316fe1f96857f439a0455ed79
# INFO:  == LLM cache == saving: default:extract:34b448920ad561f4ed0f4fcb82d15d29
# INFO: Chunk 1286 of 2236 extracted 22 Ent + 22 Rel chunk-4718a7382b94f65b50168e313009268d
# INFO:  == LLM cache == saving: default:extract:b6fa0ebc5b16951147f4d4ce7ad43c24
# INFO: Chunk 1287 of 2236 extracted 13 Ent + 16 Rel chunk-f21a28dac05bd027ddaec3bfae5eb7e3
# INFO:  == LLM cache == saving: default:extract:1ecb24438b596f36b0e0f4f7e836dddf
# INFO:  == LLM cache == saving: default:extract:a03d913dcdfd858305933bfa76d11bac
# INFO:  == LLM cache == saving: default:extract:a76760980a6c58f6fdadba642546f69e
# INFO: Chunk 1288 of 2236 extracted 16 Ent + 18 Rel chunk-56633300d418d163b656794317feee82
# INFO:  == LLM cache == saving: default:extract:372e9441b441d706a09a893bcb3e86ad
# INFO: Chunk 1289 of 2236 extracted 12 Ent + 14 Rel chunk-09e0fc150fea0d6bf7ea5e928f3017e5
# INFO:  == LLM cache == saving: default:extract:96c93a95ff4611df08a52ba6c5ece948
# INFO: Chunk 1290 of 2236 extracted 11 Ent + 10 Rel chunk-40f3b766aae26d448d74c274f9970197
# INFO:  == LLM cache == saving: default:extract:f630025e9b89fc8fa40afe53c0f9f95e
# INFO:  == LLM cache == saving: default:extract:579d542c74ac762f7a355b1309efb188
# INFO: Chunk 1291 of 2236 extracted 10 Ent + 11 Rel chunk-8bd89fd4bece763ec1cc453081c8783b
# INFO:  == LLM cache == saving: default:extract:c7b39289d5e989f8a71ac02af6d010d6
# INFO: Chunk 1292 of 2236 extracted 15 Ent + 17 Rel chunk-14f799714855ea3ec94ec49455b19cc0
# INFO:  == LLM cache == saving: default:extract:fa2d13652660277f07bbb811fd258e5f
# INFO:  == LLM cache == saving: default:extract:efed7de2001fc5218fea6d1415647c01
# INFO:  == LLM cache == saving: default:extract:756dd5d051f35abc7637269e76688766
# INFO:  == LLM cache == saving: default:extract:0c39fda88bac50576596abbbfcbbb3c4
# INFO:  == LLM cache == saving: default:extract:d6b2d6505d625f0bb27268948a09d53e
# INFO: Chunk 1293 of 2236 extracted 5 Ent + 4 Rel chunk-10d2a68f48829d23ca0b9c94d59fb8f1
# INFO:  == LLM cache == saving: default:extract:06d2969b93738b50b08e222c4e492596
# INFO:  == LLM cache == saving: default:extract:7eb9fe655229a0ba87e37f95f29a4172
# INFO:  == LLM cache == saving: default:extract:90c021f2837db9bcef412a341527d7ae
# INFO:  == LLM cache == saving: default:extract:88ba9dc85c55e92a577b3dc8c988e568
# INFO:  == LLM cache == saving: default:extract:c7a08e90c80cbeca52df236f3b74ca5c
# INFO:  == LLM cache == saving: default:extract:c2fd82160c053317bd18d06d1b7211a2
# INFO:  == LLM cache == saving: default:extract:f12947f7007a376cbeb6dcd11febd32c
# INFO:  == LLM cache == saving: default:extract:cbcdcee053a3d4d432f1484551069d0c
# INFO: Chunk 1294 of 2236 extracted 7 Ent + 7 Rel chunk-85a7697805fa41b6cf4747c227f9e40a
# INFO:  == LLM cache == saving: default:extract:223de446e9af3cfa5331f850ef5a06cc
# INFO:  == LLM cache == saving: default:extract:e877d43aa8d273924bb782668315a7b1
# INFO:  == LLM cache == saving: default:extract:32932a2922e484ff253fb7bbf63b774b
# INFO:  == LLM cache == saving: default:extract:72a389d5b465e0d48d1a84cdc497f1be
# INFO:  == LLM cache == saving: default:extract:301a5df10526c469bdff83fe710b7888
# INFO: Chunk 1295 of 2236 extracted 7 Ent + 7 Rel chunk-eceae68e3b07a8603c7e6ae1fefca425
# INFO:  == LLM cache == saving: default:extract:5b4a06c5a7a98224a2e7dc9a6d89230b
# INFO:  == LLM cache == saving: default:extract:e6272c4c4f87ebc88aacb3d77f29746d
# INFO:  == LLM cache == saving: default:extract:57c4189817c57c5206063a03e79e372e
# INFO: Chunk 1296 of 2236 extracted 8 Ent + 8 Rel chunk-3a507a58b2c1152d68f54e46165ab869
# INFO:  == LLM cache == saving: default:extract:99b3208693c7949e2157c4a511592c0e
# INFO:  == LLM cache == saving: default:extract:395b3ea067192127188f8547a3ae5fa9
# INFO: Chunk 1297 of 2236 extracted 33 Ent + 35 Rel chunk-51404dd4a17bb7681ebb27c39e5c2ea9
# INFO:  == LLM cache == saving: default:extract:1c9a142397cbd2ebe8b48afc8e332058
# INFO:  == LLM cache == saving: default:extract:b254e805e47935b18d7ff2fc7e638bcc
# INFO:  == LLM cache == saving: default:extract:08fa76c0660c36e084af3e4cc63e8f55
# INFO:  == LLM cache == saving: default:extract:2ef4b576454f0b9959c0af470038369a
# INFO: Chunk 1298 of 2236 extracted 6 Ent + 6 Rel chunk-9fd10d52ff3aac45457312fc3abfd830
# INFO:  == LLM cache == saving: default:extract:cda0a4dfee9fead8b4d9f1656b294b6e
# INFO: Chunk 1299 of 2236 extracted 25 Ent + 26 Rel chunk-65df1b8c62d4d1c612f1d6979ef14a75
# INFO:  == LLM cache == saving: default:extract:bd0c1e6217bdf7c96c399df4b6e70ac7
# INFO:  == LLM cache == saving: default:extract:3f629be0b2043e991260541ea2187c47
# INFO:  == LLM cache == saving: default:extract:a75a83e33f03dd0db2159dbe066af8e4
# INFO: Chunk 1300 of 2236 extracted 8 Ent + 8 Rel chunk-7063434078fb4a136c90939045c28af2
# INFO:  == LLM cache == saving: default:extract:fa76a9880963651a80f1a09e27f14526
# INFO:  == LLM cache == saving: default:extract:96fa5522c82958c00558c3d4cd45b5fb
# INFO: Chunk 1301 of 2236 extracted 6 Ent + 4 Rel chunk-565d2b9cdfd86202de32d1d95e6863b5
# INFO:  == LLM cache == saving: default:extract:6228d6508ecb5a4ce23b6b411efb1341
# INFO:  == LLM cache == saving: default:extract:5fb0bfa77ab21ec2c9da6859b104b7d5
# INFO:  == LLM cache == saving: default:extract:2c25fdd4c481a73843b5bb6027074e3c
# INFO:  == LLM cache == saving: default:extract:0ff441feb5b24f5973092f9b1b7fc9fd
# INFO:  == LLM cache == saving: default:extract:f184005ae466597b5e20916e4ead3fe3
# INFO: Chunk 1302 of 2236 extracted 8 Ent + 8 Rel chunk-b0a1c1cd2e53286f505b7c0313cf0751
# INFO:  == LLM cache == saving: default:extract:f58c374c8badeec08dacfd2ff31fa6ac
# INFO:  == LLM cache == saving: default:extract:e7bdf790de4748e603b037bacc46b3ff
# INFO:  == LLM cache == saving: default:extract:9127e588a4493c2b491f2ceb276ce564
# INFO: Chunk 1303 of 2236 extracted 15 Ent + 15 Rel chunk-9c7ae111954111bbbbf2f82e02fc806f
# INFO:  == LLM cache == saving: default:extract:5811c2dfb717387278f3283f4c1640a4
# INFO: Chunk 1304 of 2236 extracted 16 Ent + 21 Rel chunk-51f3ff065788c2db625ec21fcd5bdfa7
# INFO:  == LLM cache == saving: default:extract:74fa1325bc6e60a742a6066a98f91f66
# INFO:  == LLM cache == saving: default:extract:d853c84698fd967138067d92fb7e05e2
# INFO: Chunk 1305 of 2236 extracted 16 Ent + 19 Rel chunk-9d93ea6d7b36e3c1cab2a1aa54b900ea
# INFO:  == LLM cache == saving: default:extract:3ea8c4a80808e512199cfa4b832dabb7
# INFO: Chunk 1306 of 2236 extracted 25 Ent + 30 Rel chunk-96b862380adfc52020f44d05ec0e38db
# INFO:  == LLM cache == saving: default:extract:f702dfa7930be93a59f42a3c721952c6
# INFO: Chunk 1307 of 2236 extracted 15 Ent + 21 Rel chunk-5b3d4fd900db02463081455ccbfc602b
# INFO:  == LLM cache == saving: default:extract:4ac20e713a6c4a2e85dc2afe4c4d1862
# INFO: Chunk 1308 of 2236 extracted 12 Ent + 19 Rel chunk-c5f701b4d64db4c047449a464d581715
# INFO:  == LLM cache == saving: default:extract:b3935b6a5c274e3c37177707f56aea7b
# INFO: Chunk 1309 of 2236 extracted 17 Ent + 16 Rel chunk-dbd2d431567239d3c2a12ce3e810c195
